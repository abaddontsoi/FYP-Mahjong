# %%
# @title Train the classification model
from ultralytics import YOLO

model = YOLO('yolo11s-cls.yaml')
model.reset_weights()


result = model.train(
    data='classification_raw_data/train',
    epochs=100,
    device=-1
)
# Out:
# YOLO11s-cls summary: 86 layers, 6,724,008 parameters, 6,724,008 gradients, 13.2 GFLOPs
# Searching for 1 idle GPUs with free memory >= 20.0% and free utilization >= 0.0%...
# WARNING No GPUs met criteria (free memory >= 20.0% and free utilization >= 0.0%).
# Ultralytics 8.3.243  Python-3.14.0 torch-2.9.1+cu130 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=classification_raw_data/train, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\FYP-Tile-Detection\runs\classify\train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# WARNING Dataset 'split=train' not found at D:\FYP-Tile-Detection\classification_raw_data\train\train
# Found 100967 images in subdirectories. Attempting to split...
# Splitting D:\FYP-Tile-Detection\classification_raw_data\train (43 classes, 100967 images) into 80% train, 20% val...
# Split complete in D:\FYP-Tile-Detection\classification_raw_data\train_split
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train... found 80756 images in 43 classes
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val... found 20211 images in 43 classes
# test: None...
# Overriding model.yaml nc=1000 with nc=43
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    713003  ultralytics.nn.modules.head.Classify         [512, 43]
# YOLO11s-cls summary: 86 layers, 5,498,091 parameters, 5,498,091 gradients, 12.2 GFLOPs
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 5.83.2 MB/s, size: 5.5 KB)
# train: Scanning D:\FYP-Tile-Detection\classification_raw_data\train_split\train... 80712 images, 44 corrupt: 100% ━━━━━━━━━━━━ 80712/80712 172.5Mit/s 0.0s
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\1m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_169262.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\1m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_957032.jpg: ignoring corrupt image/label: image size (24, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\1m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_957679.jpg: ignoring corrupt image/label: image size (21, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\1p\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_958668.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\1s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_955881.jpg: ignoring corrupt image/label: image size (25, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\1s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_973958.jpg: ignoring corrupt image/label: image size (25, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\2m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_956227.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\2p\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_959083.jpg: ignoring corrupt image/label: image size (24, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\2p\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_977645.jpg: ignoring corrupt image/label: image size (24, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\2z\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_958824.jpg: ignoring corrupt image/label: image size (21, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\2z\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_977325.jpg: ignoring corrupt image/label: image size (21, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\3m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_164163.jpg: ignoring corrupt image/label: image size (21, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\3m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_967115.jpg: ignoring corrupt image/label: image size (21, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\3s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_168847.jpg: ignoring corrupt image/label: image size (21, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\3s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_972238.jpg: ignoring corrupt image/label: image size (21, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\3z\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_958006.jpg: ignoring corrupt image/label: image size (19, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\3z\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_976566.jpg: ignoring corrupt image/label: image size (19, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_164029.jpg: ignoring corrupt image/label: image size (27, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_957539.jpg: ignoring corrupt image/label: image size (23, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_966979.jpg: ignoring corrupt image/label: image size (27, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_975994.jpg: ignoring corrupt image/label: image size (23, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_165032.jpg: ignoring corrupt image/label: image size (21, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_959318.jpg: ignoring corrupt image/label: image size (24, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_968458.jpg: ignoring corrupt image/label: image size (21, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_968623.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\4s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_977917.jpg: ignoring corrupt image/label: image size (24, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\5s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_165242.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\5s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_968767.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\6p\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_164458.jpg: ignoring corrupt image/label: image size (21, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\6s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_166263.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\6s\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_969023.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\6z\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_168746.jpg: ignoring corrupt image/label: image size (17, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\6z\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_972042.jpg: ignoring corrupt image/label: image size (17, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_956073.jpg: ignoring corrupt image/label: image size (23, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_974102.jpg: ignoring corrupt image/label: image size (23, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7p\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_164669.jpg: ignoring corrupt image/label: image size (23, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7p\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_164811.jpg: ignoring corrupt image/label: image size (23, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7p\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_967631.jpg: ignoring corrupt image/label: image size (23, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7z\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_957222.jpg: ignoring corrupt image/label: image size (20, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\7z\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_975129.jpg: ignoring corrupt image/label: image size (20, 7) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\8m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_168951.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\8m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_957390.jpg: ignoring corrupt image/label: image size (24, 8) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\8m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_972851.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# train: D:\FYP-Tile-Detection\classification_raw_data\train_split\train\8m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_975324.jpg: ignoring corrupt image/label: image size (24, 8) <10 pixels
# val: Fast image access  (ping: 0.00.0 ms, read: 1.81.3 MB/s, size: 6.6 KB)
# val: Scanning D:\FYP-Tile-Detection\classification_raw_data\train_split\val... 20201 images, 10 corrupt: 100% ━━━━━━━━━━━━ 20211/20211 1.6Kit/s 12.5s<0.0s
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\1m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_973237.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\1m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_975018.jpg: ignoring corrupt image/label: image size (24, 9) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\1m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_976169.jpg: ignoring corrupt image/label: image size (21, 7) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\1p\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_977189.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\2m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_974271.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\3m\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_958132.jpg: ignoring corrupt image/label: image size (25, 8) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\3m\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_976695.jpg: ignoring corrupt image/label: image size (25, 8) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\4s\M-3_png_jpg.rf.e1d8b21190b12adc9bfe82127dd0263c_20251230_162514_165136.jpg: ignoring corrupt image/label: image size (23, 9) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\6p\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_967365.jpg: ignoring corrupt image/label: image size (21, 9) <10 pixels
# val: D:\FYP-Tile-Detection\classification_raw_data\train_split\val\7p\M-3_png_jpg.rf.e9bc23cd06d81d0b8fd7b7c92572a610_20251230_162514_967514.jpg: ignoring corrupt image/label: image size (23, 8) <10 pixels
# val: New cache created: D:\FYP-Tile-Detection\classification_raw_data\train_split\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to D:\FYP-Tile-Detection\runs\classify\train3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.449G      2.724         16        224: 91% ━━━━━━━━━━╸─ 4601/5045 27.2it/s 3:39<16.3s

# %%
model.save(f'MJ_tile_detection_classification_yolo11.pt')
